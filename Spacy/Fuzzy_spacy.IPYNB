# %%
import spacy
import pandas as pd
from rapidfuzz import process, fuzz
import re

# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz, process
import spacy

# Cargar el DataFrame original con entidades
df = pd.read_csv("df_con_entidades_por_etiqueta_TEST.csv")

# Cargar el DataFrame con las colonias conocidas (nombre y geometría)
df_colonias = pd.read_csv("Colonias_Filtradas.csv")

# Función para normalizar el prefijo y eliminar puntos
def normalizar_prefijos(entidad):
    entidad = entidad.lower()  # Ignorar mayúsculas/minúsculas

    # Reemplazar prefijos solo si están al inicio
    entidad = re.sub(r"^av( |$)", "avenida ", entidad)  # Reemplaza 'av' o 'ave' al inicio
    entidad = re.sub(r"^ave( |$)", "avenida ", entidad)
    entidad = re.sub(r"^col( |$)", "", entidad)  # Elimina el prefijo 'col' o 'colonia'
    entidad = re.sub(r"^colonia( |$)", "", entidad)
    
    entidad = entidad.replace(".", "")  # Eliminar puntos
    entidad = entidad.replace(" ", "")
    return entidad.strip()  # Eliminar espacios en blanco innecesarios

# Función para encontrar la mejor coincidencia y porcentaje
def encontrar_mejor_coincidencia(entidad, df_colonias):
    # Normalizar los nombres en la base de datos antes de comparar
    nombres_colonias_normalizados = [normalizar_prefijos(nombre) for nombre in df_colonias['SETT_NAME']]
    # Encontrar la mejor coincidencia y el puntaje
    mejor_coincidencia, score = process.extractOne(entidad, nombres_colonias_normalizados, scorer=fuzz.token_sort_ratio)
    
    # Encontrar el índice de la mejor coincidencia
    idx = nombres_colonias_normalizados.index(mejor_coincidencia)
    
    return mejor_coincidencia, score, idx

# Crear un nuevo DataFrame para almacenar las coincidencias válidas
df_actualizado = pd.DataFrame(columns=df.columns)

# Iterar sobre cada fila de la columna 'colonia'
for idx, colonia in df['colonia'].items():
    if pd.isna(colonia):  # Saltar filas vacías
        continue
    
    # Normalizar el nombre de la colonia antes de comparar
    colonia_normalizada = normalizar_prefijos(colonia)
    
    # Encontrar la mejor coincidencia con la base de datos conocida
    mejor_coincidencia, score, idx_colonia = encontrar_mejor_coincidencia(colonia_normalizada, df_colonias)
    
    # Si la similitud es mayor al 75%, sobrescribir la colonia y agregar la geometría
    if score > 75:
        df.loc[idx, 'colonia'] = mejor_coincidencia  # Sobrescribir la colonia
        df.loc[idx, 'geometría'] = df_colonias.iloc[idx_colonia]['geometry']  # Agregar la geometría
        df_actualizado = pd.concat([df_actualizado, df.loc[[idx]]])  # Añadir la fila actualizada
        print(f"Fila {idx}: Reemplazando '{colonia_normalizada}' por '{mejor_coincidencia}' con {score}% de similitud")
    else:
        print(f"Fila {idx}: No se encontró coincidencia suficiente para '{colonia_normalizada}' (Similitud: {score}%)")

# Guardar el DataFrame actualizado en un archivo CSV
#df_actualizado.to_csv('df_con_colonias_actualizadas.csv', index=False)

print("DataFrame actualizado y guardado como 'df_con_colonias_actualizadas.csv'")
# Out:
# Fila 0: Reemplazando 'bosquesdelahuasteca' por 'bosquesdelahuasteca' con 100% de similitud
# Fila 1: Reemplazando 'vistahermosa' por 'vistahermosa' con 100% de similitud
# Fila 2: Reemplazando 'potreroanáhuac' por 'potreroanahuac' con 96% de similitud
# Fila 3: Reemplazando 'satéliteacueductomonterrey' por 'sateliteacueducto' con 76% de similitud
# Fila 4: Reemplazando 'arboledasdelasillaguadalupe' por 'arboledasdelasilla' con 80% de similitud
# Fila 5: Reemplazando 'villasdelmirador' por 'fraccvillasdelmirador' con 86% de similitud
# Fila 9: No se encontró coincidencia suficiente para 'hgojal' (Similitud: 55%)
# Fila 79: No se encontró coincidencia suficiente para 'ciudadidealdanielcarrillo' (Similitud: 63%)
# Fila 148: No se encontró coincidencia suficiente para 'cerveradelrío' (Similitud: 74%)
# Fila 152: No se encontró coincidencia suficiente para 'burgerking' (Similitud: 53%)
# Fila 167: No se encontró coincidencia suficiente para 'anáhuacnuevoleón' (Similitud: 70%)
# Fila 175: Reemplazando 'granjapostaldesur' por 'granjapostal' con 83% de similitud
# Fila 180: No se encontró coincidencia suficiente para 'delegaciónmargaritas' (Similitud: 75%)
# Fila 183: No se encontró coincidencia suficiente para 'ciudadeltransmetro' (Similitud: 62%)
# Fila 200: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 202: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 207: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 216: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 247: No se encontró coincidencia suficiente para 'caracolmovilizó' (Similitud: 67%)
# Fila 248: Reemplazando 'ciudadsatelitemty' por 'ciudadsatelite' con 90% de similitud
# Fila 249: Reemplazando 'nuevamorelos' por 'nuevamorelos' con 100% de similitud
# Fila 255: No se encontró coincidencia suficiente para 'lotebaldíoregio' (Similitud: 61%)
# Fila 258: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 259: Reemplazando 'villamontaña' por 'villamontaña' con 100% de similitud
# Fila 261: No se encontró coincidencia suficiente para 'ébanosnorte' (Similitud: 70%)
# Fila 264: Reemplazando 'contrytesoro' por 'contryeltesoro' con 92% de similitud
# Fila 266: Reemplazando 'reforma' por 'reforma' con 100% de similitud
# Fila 281: Reemplazando 'fuentesdelvalle' por 'fuentesdelvalle' con 100% de similitud
# Fila 295: Reemplazando 'sanjemo' por 'sanjemo' con 100% de similitud
# Fila 296: Reemplazando 'sanjerónimo' por 'sanjeronimo' con 95% de similitud
# Fila 297: Reemplazando 'alafama' por 'lafama' con 92% de similitud
# Fila 303: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 305: Reemplazando 'niñoartillero' por 'niñoartillero' con 100% de similitud
# Fila 307: Reemplazando 'capistrana' por 'capistrano' con 90% de similitud
# Fila 308: No se encontró coincidencia suficiente para 'cosmopolisen' (Similitud: 74%)
# Fila 309: Reemplazando 'cosmopolis' por 'fracccosmopolis' con 80% de similitud
# Fila 310: Reemplazando 'alfonsoreyes' por 'alfonsoreyes' con 100% de similitud
# Fila 312: No se encontró coincidencia suficiente para 'barriodelaindustria' (Similitud: 69%)
# Fila 313: Reemplazando 'riberasdelrío' por 'riberasdelrio' con 96% de similitud
# Fila 315: Reemplazando 'andréscaballero' por 'andrescaballeromoreno' con 80% de similitud
# Fila 317: Reemplazando 'laderasdelmirador' por 'laderasdelmirador' con 100% de similitud
# Fila 318: Reemplazando 'jardinesdelamoderna' por 'jardinesdelamoderna' con 100% de similitud
# Fila 319: Reemplazando 'valledesan' por 'valledesofia' con 82% de similitud
# Fila 320: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 321: Reemplazando 'ancira' por 'ancira' con 100% de similitud
# Fila 322: Reemplazando 'lasencinas' por 'lasencinas' con 100% de similitud
# Fila 323: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 333: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 347: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 383: Reemplazando 'zonacumbres' por 'cumbres' con 78% de similitud
# Fila 444: No se encontró coincidencia suficiente para 'ciudadelpersonal' (Similitud: 62%)
# Fila 457: No se encontró coincidencia suficiente para 'ciudadmaneja' (Similitud: 64%)
# Fila 472: Reemplazando 'deportivoobispado' por 'deportivoobispado' con 100% de similitud
# Fila 475: Reemplazando 'lomalarga' por 'lomalarga' con 100% de similitud
# Fila 478: No se encontró coincidencia suficiente para 'barriodelaindustria' (Similitud: 69%)
# Fila 493: Reemplazando 'héctorcaballero' por 'hectorcaballero' con 97% de similitud
# Fila 499: No se encontró coincidencia suficiente para 'unidadelpueblo' (Similitud: 69%)
# Fila 528: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 531: Reemplazando 'laindependencia' por 'independencia' con 93% de similitud
# Fila 535: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 562: No se encontró coincidencia suficiente para 'alianzaenmonterrey' (Similitud: 67%)
# Fila 564: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 575: Reemplazando 'franciscovilla' por 'franciscovilla' con 100% de similitud
# Fila 604: No se encontró coincidencia suficiente para 'cfecontigocfemx' (Similitud: 47%)
# Fila 605: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 611: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 615: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 619: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 625: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 714: Reemplazando 'laalianza' por 'laalianza' con 100% de similitud
# Fila 741: No se encontró coincidencia suficiente para 'cfecontigocfemx' (Similitud: 47%)
# Fila 748: No se encontró coincidencia suficiente para 'aztecacomunidadmagssp' (Similitud: 50%)
# Fila 766: No se encontró coincidencia suficiente para 'unidadelpueblo' (Similitud: 69%)
# Fila 773: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 788: No se encontró coincidencia suficiente para 'hgojal' (Similitud: 55%)
# Fila 789: Reemplazando 'fomerrey' por 'fomerrey4' con 94% de similitud
# Fila 790: Reemplazando 'alafama' por 'lafama' con 92% de similitud
# Fila 798: No se encontró coincidencia suficiente para 'orizabadebidoa' (Similitud: 67%)
# Fila 799: Reemplazando 'orizaba' por 'orizaba' con 100% de similitud
# Fila 818: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 828: No se encontró coincidencia suficiente para 'hgojal' (Similitud: 55%)
# Fila 847: No se encontró coincidencia suficiente para 'bella' (Similitud: 71%)
# Fila 876: No se encontró coincidencia suficiente para 'albaterraresidencial' (Similitud: 75%)
# Fila 877: Reemplazando 'venustianocarranza' por 'venustianocarranza' con 100% de similitud
# Fila 889: No se encontró coincidencia suficiente para 'repúblicamexicana' (Similitud: 59%)
# Fila 908: Reemplazando 'elsabino' por 'elsabino' con 100% de similitud
# Fila 926: Reemplazando 'celestino' por 'celestinogasca' con 78% de similitud
# Fila 943: Reemplazando 'eluro' por 'eluro' con 100% de similitud
# Fila 956: No se encontró coincidencia suficiente para 'cerveradelrío' (Similitud: 74%)
# Fila 960: No se encontró coincidencia suficiente para 'burgerking' (Similitud: 53%)
# Fila 973: Reemplazando 'chapultepec' por 'chapultepec' con 100% de similitud
# Fila 976: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 996: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 998: Reemplazando 'fernandoamilpa' por 'fernandoamilpa' con 100% de similitud
# Fila 1000: Reemplazando 'paloblanco' por 'paloblanco' con 100% de similitud
# Fila 1001: Reemplazando 'cantú' por 'cantu' con 89% de similitud
# Fila 1003: No se encontró coincidencia suficiente para 'caracolenlaciudad' (Similitud: 58%)
# Fila 1004: Reemplazando 'olinala' por 'olinala' con 100% de similitud
# Fila 1009: Reemplazando 'nuevoamanecer' por 'nuevoamanecer1rasecc' con 79% de similitud
# Fila 1011: No se encontró coincidencia suficiente para 'carrereraalaredo' (Similitud: 59%)
# Fila 1012: Reemplazando 'sanmiguel' por 'sanmiguel' con 100% de similitud
# Fila 1014: Reemplazando 'fernandoamilpa' por 'fernandoamilpa' con 100% de similitud
# Fila 1015: Reemplazando 'buenosaires' por 'buenosaires' con 100% de similitud
# Fila 1016: Reemplazando 'vistahermosa' por 'vistahermosa' con 100% de similitud
# Fila 1017: Reemplazando 'mirasol' por 'mirasol' con 100% de similitud
# Fila 1019: No se encontró coincidencia suficiente para 'agropecuaria' (Similitud: 60%)
# Fila 1020: No se encontró coincidencia suficiente para 'barriolaindustriazonanortedemonterrey' (Similitud: 64%)
# Fila 1021: Reemplazando 'larepública' por 'larepublica' con 95% de similitud
# Fila 1022: Reemplazando 'lázarocárdenas' por 'lazarocardenas' con 92% de similitud
# Fila 1025: Reemplazando 'central' por 'central' con 100% de similitud
# Fila 1026: Reemplazando 'loslirios' por 'loslirios' con 100% de similitud
# Fila 1028: Reemplazando 'moderna' por 'moderna' con 100% de similitud
# Fila 1029: Reemplazando 'cantumonterrey' por 'monterrey' con 78% de similitud
# Fila 1039: Reemplazando 'buenosaires' por 'buenosaires' con 100% de similitud
# Fila 1061: No se encontró coincidencia suficiente para 'vistareal' (Similitud: 74%)
# Fila 1096: No se encontró coincidencia suficiente para 'aleganque' (Similitud: 67%)
# Fila 1097: Reemplazando 'vecinosdesanpedrogarzagarcia' por 'centrodesanpedrogarzagarcia' con 87% de similitud
# Fila 1098: Reemplazando 'constituyentesdequerétaro' por 'constituyentesdequeretarosect1' con 89% de similitud
# Fila 1128: Reemplazando 'buenosaires' por 'buenosaires' con 100% de similitud
# Fila 1159: Reemplazando 'delcarmen' por 'delcarmen' con 100% de similitud
# Fila 1163: Reemplazando 'buenosaires' por 'buenosaires' con 100% de similitud
# Fila 1194: No se encontró coincidencia suficiente para 'ciudadlaciudadparacrecer' (Similitud: 59%)
# Fila 1197: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 1198: Reemplazando 'colinasdelvalle' por 'colinasdelasilla' con 84% de similitud
# Fila 1199: Reemplazando 'cumbres' por 'cumbres' con 100% de similitud
# Fila 1200: Reemplazando 'cumbres' por 'cumbres' con 100% de similitud
# Fila 1201: Reemplazando 'sanpedro' por 'sanpedro' con 100% de similitud
# Fila 1202: Reemplazando 'elobispo' por 'elobispo' con 100% de similitud
# Fila 1203: Reemplazando 'cumbresdelvalle' por 'brisasdelvalle' con 76% de similitud
# Fila 1204: Reemplazando 'bosquesdelahuasteca' por 'bosquesdelahuasteca' con 100% de similitud
# Fila 1205: Reemplazando 'infonavitlahuasteca' por 'infonavitlahuasteca' con 100% de similitud
# Fila 1206: Reemplazando 'cordillerasdelvirrey' por 'fracccordillerasdelvirrey' con 89% de similitud
# Fila 1207: Reemplazando 'pedregaldelahuasteca' por 'pedregaldelahuasteca' con 100% de similitud
# Fila 1208: Reemplazando 'vistamontaña' por 'vistamontaña' con 100% de similitud
# Fila 1209: Reemplazando 'pedregallasillamonterrey' por 'pedregallasilla' con 77% de similitud
# Fila 1210: Reemplazando 'revolucióner' por 'revolucion' con 86% de similitud
# Fila 1211: No se encontró coincidencia suficiente para 'sangilberto' (Similitud: 73%)
# Fila 1212: Reemplazando 'contrysol' por 'countrysol' con 95% de similitud
# Fila 1213: Reemplazando 'buenosaires' por 'buenosaires' con 100% de similitud
# Fila 1214: Reemplazando 'realdelvalle' por 'realdelvalle' con 100% de similitud
# Fila 1215: No se encontró coincidencia suficiente para 'independenciamonterrey' (Similitud: 74%)
# Fila 1218: No se encontró coincidencia suficiente para 'hgojal' (Similitud: 55%)
# Fila 1288: No se encontró coincidencia suficiente para 'ciudadidealdanielcarrillo' (Similitud: 63%)
# Fila 1353: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 1360: No se encontró coincidencia suficiente para 'cerveradelrío' (Similitud: 74%)
# Fila 1364: No se encontró coincidencia suficiente para 'burgerking' (Similitud: 53%)
# Fila 1379: No se encontró coincidencia suficiente para 'anáhuacnuevoleón' (Similitud: 70%)
# Fila 1387: Reemplazando 'granjapostaldesur' por 'granjapostal' con 83% de similitud
# Fila 1390: No se encontró coincidencia suficiente para 'delegaciónmargaritas' (Similitud: 75%)
# Fila 1393: No se encontró coincidencia suficiente para 'ciudadeltransmetro' (Similitud: 62%)
# Fila 1411: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1416: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1425: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1429: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1466: No se encontró coincidencia suficiente para 'caracolmovilizó' (Similitud: 67%)
# Fila 1467: Reemplazando 'ciudadsatelitemty' por 'ciudadsatelite' con 90% de similitud
# Fila 1468: Reemplazando 'nuevamorelos' por 'nuevamorelos' con 100% de similitud
# Fila 1474: No se encontró coincidencia suficiente para 'lotebaldíoregio' (Similitud: 61%)
# Fila 1477: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 1478: Reemplazando 'villamontaña' por 'villamontaña' con 100% de similitud
# Fila 1480: No se encontró coincidencia suficiente para 'ébanosnorte' (Similitud: 70%)
# Fila 1483: Reemplazando 'contrytesoro' por 'contryeltesoro' con 92% de similitud
# Fila 1485: Reemplazando 'reforma' por 'reforma' con 100% de similitud
# Fila 1499: Reemplazando 'sanjerónimo' por 'sanjeronimo' con 95% de similitud
# Fila 1500: Reemplazando 'alafama' por 'lafama' con 92% de similitud
# Fila 1506: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 1508: Reemplazando 'niñoartillero' por 'niñoartillero' con 100% de similitud
# Fila 1510: Reemplazando 'capistrana' por 'capistrano' con 90% de similitud
# Fila 1511: No se encontró coincidencia suficiente para 'cosmopolisen' (Similitud: 74%)
# Fila 1512: Reemplazando 'cosmopolis' por 'fracccosmopolis' con 80% de similitud
# Fila 1513: Reemplazando 'alfonsoreyes' por 'alfonsoreyes' con 100% de similitud
# Fila 1515: No se encontró coincidencia suficiente para 'barriodelaindustria' (Similitud: 69%)
# Fila 1516: Reemplazando 'riberasdelrío' por 'riberasdelrio' con 96% de similitud
# Fila 1518: Reemplazando 'andréscaballero' por 'andrescaballeromoreno' con 80% de similitud
# Fila 1520: Reemplazando 'laderasdelmirador' por 'laderasdelmirador' con 100% de similitud
# Fila 1521: Reemplazando 'jardinesdelamoderna' por 'jardinesdelamoderna' con 100% de similitud
# Fila 1522: Reemplazando 'valledesan' por 'valledesofia' con 82% de similitud
# Fila 1523: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 1524: Reemplazando 'ancira' por 'ancira' con 100% de similitud
# Fila 1525: Reemplazando 'lasencinas' por 'lasencinas' con 100% de similitud
# Fila 1526: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 1527: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 1536: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 1552: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 1585: Reemplazando 'zonacumbres' por 'cumbres' con 78% de similitud
# Fila 1593: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 1665: Reemplazando 'deportivoobispado' por 'deportivoobispado' con 100% de similitud
# Fila 1668: Reemplazando 'lomalarga' por 'lomalarga' con 100% de similitud
# Fila 1671: No se encontró coincidencia suficiente para 'barriodelaindustria' (Similitud: 69%)
# Fila 1674: Reemplazando 'bosquesdelascumbres' por 'bosquesdelascumbres' con 100% de similitud
# Fila 1686: Reemplazando 'héctorcaballero' por 'hectorcaballero' con 97% de similitud
# Fila 1717: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 1720: Reemplazando 'laindependencia' por 'independencia' con 93% de similitud
# Fila 1724: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 1747: No se encontró coincidencia suficiente para 'alianzaenmonterrey' (Similitud: 67%)
# Fila 1761: Reemplazando 'franciscovilla' por 'franciscovilla' con 100% de similitud
# Fila 1792: No se encontró coincidencia suficiente para 'cfecontigocfemx' (Similitud: 47%)
# Fila 1799: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1803: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1809: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1813: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1818: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 1903: Reemplazando 'laalianza' por 'laalianza' con 100% de similitud
# Fila 1924: No se encontró coincidencia suficiente para 'cfecontigocfemx' (Similitud: 47%)
# Fila 1932: No se encontró coincidencia suficiente para 'aztecacomunidadmagssp' (Similitud: 50%)
# Fila 1952: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 1967: No se encontró coincidencia suficiente para 'hgojal' (Similitud: 55%)
# Fila 1968: Reemplazando 'fomerrey' por 'fomerrey4' con 94% de similitud
# Fila 1969: Reemplazando 'alafama' por 'lafama' con 92% de similitud
# Fila 1985: No se encontró coincidencia suficiente para 'orizabadebidoa' (Similitud: 67%)
# Fila 1986: Reemplazando 'orizaba' por 'orizaba' con 100% de similitud
# Fila 2005: Reemplazando 'ciudadideal' por 'ciudadidealsect2' con 81% de similitud
# Fila 2007: No se encontró coincidencia suficiente para 'centrosanpedro' (Similitud: 73%)
# Fila 2008: No se encontró coincidencia suficiente para 'leonesmonterrey' (Similitud: 75%)
# Fila 2014: Reemplazando 'raúlcaballero' por 'raulcaballero' con 96% de similitud
# Fila 2015: No se encontró coincidencia suficiente para 'samsararesidencialsector' (Similitud: 67%)
# Fila 2016: Reemplazando 'ciudadideal' por 'ciudadidealsect2' con 81% de similitud
# Fila 2059: Reemplazando 'capistrana' por 'capistrano' con 90% de similitud
# Fila 2083: No se encontró coincidencia suficiente para 'ciudadidealdanielcarrillo' (Similitud: 63%)
# Fila 2147: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 2154: No se encontró coincidencia suficiente para 'cerveradelrío' (Similitud: 74%)
# Fila 2158: No se encontró coincidencia suficiente para 'burgerking' (Similitud: 53%)
# Fila 2173: No se encontró coincidencia suficiente para 'anáhuacnuevoleón' (Similitud: 70%)
# Fila 2181: Reemplazando 'granjapostaldesur' por 'granjapostal' con 83% de similitud
# Fila 2182: No se encontró coincidencia suficiente para 'delegaciónmargaritas' (Similitud: 75%)
# Fila 2185: No se encontró coincidencia suficiente para 'ciudadeltransmetro' (Similitud: 62%)
# Fila 2205: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2210: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2219: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2223: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2257: No se encontró coincidencia suficiente para 'caracolmovilizó' (Similitud: 67%)
# Fila 2258: Reemplazando 'ciudadsatelitemty' por 'ciudadsatelite' con 90% de similitud
# Fila 2259: Reemplazando 'nuevamorelos' por 'nuevamorelos' con 100% de similitud
# Fila 2265: No se encontró coincidencia suficiente para 'lotebaldíoregio' (Similitud: 61%)
# Fila 2268: Reemplazando 'hacienda' por 'lahacienda' con 89% de similitud
# Fila 2269: Reemplazando 'villamontaña' por 'villamontaña' con 100% de similitud
# Fila 2271: No se encontró coincidencia suficiente para 'ébanosnorte' (Similitud: 70%)
# Fila 2274: Reemplazando 'contrytesoro' por 'contryeltesoro' con 92% de similitud
# Fila 2276: Reemplazando 'reforma' por 'reforma' con 100% de similitud
# Fila 2286: Reemplazando 'fuentesdelvalle' por 'fuentesdelvalle' con 100% de similitud
# Fila 2300: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 2315: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 2324: Reemplazando 'delvalle' por 'delvalle' con 100% de similitud
# Fila 2326: Reemplazando 'niñoartillero' por 'niñoartillero' con 100% de similitud
# Fila 2328: Reemplazando 'capistrana' por 'capistrano' con 90% de similitud
# Fila 2329: No se encontró coincidencia suficiente para 'cosmopolisen' (Similitud: 74%)
# Fila 2330: Reemplazando 'cosmopolis' por 'fracccosmopolis' con 80% de similitud
# Fila 2331: Reemplazando 'alfonsoreyes' por 'alfonsoreyes' con 100% de similitud
# Fila 2333: No se encontró coincidencia suficiente para 'barriodelaindustria' (Similitud: 69%)
# Fila 2334: Reemplazando 'riberasdelrío' por 'riberasdelrio' con 96% de similitud
# Fila 2336: Reemplazando 'andréscaballero' por 'andrescaballeromoreno' con 80% de similitud
# Fila 2338: Reemplazando 'laderasdelmirador' por 'laderasdelmirador' con 100% de similitud
# Fila 2339: Reemplazando 'jardinesdelamoderna' por 'jardinesdelamoderna' con 100% de similitud
# Fila 2340: Reemplazando 'valledesan' por 'valledesofia' con 82% de similitud
# Fila 2341: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 2342: Reemplazando 'ancira' por 'ancira' con 100% de similitud
# Fila 2343: Reemplazando 'lasencinas' por 'lasencinas' con 100% de similitud
# Fila 2344: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 2345: Reemplazando 'topochico' por 'topochico' con 100% de similitud
# Fila 2355: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 2369: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 2394: Reemplazando 'zonacumbres' por 'cumbres' con 78% de similitud
# Fila 2402: Reemplazando 'viñedosensantacatarina' por 'torresdesantacatarina' con 76% de similitud
# Fila 2406: Reemplazando 'zonacumbres' por 'cumbres' con 78% de similitud
# Fila 2475: No se encontró coincidencia suficiente para 'ciudadmaneja' (Similitud: 64%)
# Fila 2488: Reemplazando 'héctorcaballero' por 'hectorcaballero' con 97% de similitud
# Fila 2509: Reemplazando 'mitrasnorte' por 'mitrasnorte' con 100% de similitud
# Fila 2512: Reemplazando 'laindependencia' por 'independencia' con 93% de similitud
# Fila 2516: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 2526: Reemplazando 'altavistaen' por 'altavista' con 90% de similitud
# Fila 2531: No se encontró coincidencia suficiente para 'alianzaenmonterrey' (Similitud: 67%)
# Fila 2545: No se encontró coincidencia suficiente para 'satélitealsur' (Similitud: 62%)
# Fila 2575: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 2576: Reemplazando 'elescorial' por 'elescorial' con 100% de similitud
# Fila 2587: No se encontró coincidencia suficiente para 'cfecontigocfemx' (Similitud: 47%)
# Fila 2594: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2599: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2604: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2609: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2614: Reemplazando 'blaschumacera' por 'blaschumacero' con 92% de similitud
# Fila 2698: Reemplazando 'laalianza' por 'laalianza' con 100% de similitud
# Fila 2719: No se encontró coincidencia suficiente para 'aztecacomunidadmagssp' (Similitud: 50%)
# Fila 2755: Reemplazando 'laindependencia' por 'independencia' con 93% de similitud
# Fila 2768: No se encontró coincidencia suficiente para 'aztecacomunidadmagssp' (Similitud: 50%)
# Fila 2773: No se encontró coincidencia suficiente para 'orizabadebidoa' (Similitud: 67%)
# Fila 2774: Reemplazando 'orizaba' por 'orizaba' con 100% de similitud
# DataFrame actualizado y guardado como 'df_con_colonias_actualizadas.csv'
